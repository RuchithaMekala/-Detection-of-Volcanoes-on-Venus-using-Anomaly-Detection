# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

#pca_res = pd.read_csv("/content/drive/MyDrive/Data_Mining_Project/Results/pca_results.csv")

ae_res = pd.read_csv("/content/drive/MyDrive/Data_Mining_Project/Results/ae_results.csv")

# %%
df = ae_res.iloc[:11][:]
df
# Out:
#     Dimensions  Threshold  Precision    Recall  F1_score  Train_accuracy
# 0            2       5000   0.500882  1.000000  0.667451        0.003481
# 1            2       6000   0.501425  0.992248  0.666194        0.014225
# 2            2       7000   0.503040  0.933051  0.653666        0.076271
# 3            2       8000   0.500669  0.790698  0.613115        0.196883
# 4            2       9000   0.490305  0.623679  0.549007        0.328390
# 5            2      10000   0.477920  0.472868  0.475381        0.472760
# 6            2      11000   0.464545  0.360113  0.405717        0.579146
# 7            2      12000   0.453125  0.265680  0.334962        0.673426
# 8            2      13000   0.435764  0.176885  0.251629        0.782688
# 9            2      14000   0.434109  0.118393  0.186047        0.842766
# 10           2      15000   0.403433  0.066244  0.113801        0.896489

# %%
df1= ae_res[11:22][:]
df1
# Out:
#     Dimensions  Threshold  Precision    Recall  F1_score  Train_accuracy
# 11           3       5000   0.501059  1.000000  0.667608        0.003329
# 12           3       6000   0.501782  0.992248  0.666509        0.013923
# 13           3       7000   0.503425  0.932347  0.653818        0.075817
# 14           3       8000   0.500893  0.790698  0.613282        0.196731
# 15           3       9000   0.484384  0.622974  0.545006        0.332324
# 16           3      10000   0.474540  0.472868  0.473703        0.474425
# 17           3      11000   0.473587  0.360113  0.409127        0.575969
# 18           3      12000   0.462485  0.264975  0.336918        0.671156
# 19           3      13000   0.468284  0.176885  0.256777        0.776937
# 20           3      14000   0.442971  0.117689  0.185969        0.841404
# 21           3      15000   0.415929  0.066244  0.114286        0.895430

# %%
df2 = ae_res.iloc[22:33][:]
# df2

# %%
df3 = ae_res.iloc[33:44][:]

# %%
df4 = ae_res.iloc[44:55][:]

# %%
df5 = ae_res.iloc[55:66][:]

# %%
df6 = ae_res.iloc[66:77][:]

# %%
df7 = ae_res.iloc[77:88][:]

# %%
df8 = ae_res.iloc[88:99][:]

# %%
plt.plot(df8['Threshold'], df8['Train_accuracy'], label='Train Accuracy', color = 'red')
plt.plot(df8['Threshold'], df8['Precision'], label='Precision',color = 'orange')
plt.plot(df8['Threshold'], df8['Recall'], label='Recall',color = 'blue')
plt.plot(df8['Threshold'], df8['F1_score'], label='F1 Score',color = 'green')
plt.xlabel("Error Threshold Values")
plt.ylabel("Score ")
# plt.legend(title='score', bbox_to_anchor = (1,1.35), loc='upper right', )
plt.legend(title='score', loc='upper right')
plt.title("Trend in results, where Encoding Dimensions = 10")
plt.show()
