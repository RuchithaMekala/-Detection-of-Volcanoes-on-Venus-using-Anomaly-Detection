# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

pca_res = pd.read_csv("/content/drive/MyDrive/Data_Mining_Project/Results/pca_results.csv")

ae_res = pd.read_csv("/content/drive/MyDrive/Data_Mining_Project/Results/ae_results.csv")

# %%
pca_res.head()
# Out:
#    n_components  Threshold  Precision    Recall  F1_score  Train_accuracy
# 0             2         50   0.501236  1.000000  0.667765        0.001816
# 1             2         60   0.502123  1.000000  0.668551        0.003481
# 2             2         70   0.503372  0.999295  0.669500        0.008172
# 3             2         80   0.505908  0.995772  0.670940        0.016041
# 4             2         90   0.511840  0.990134  0.674832        0.034958

# %%
len(pca_res)
# Out:
# 225

# %%
225/5
# Out:
# 45.0

# %%
df = pca_res.iloc[:45][:]
df.head()
# Out:
#    n_components  Threshold  Precision    Recall  F1_score  Train_accuracy
# 0             2         50   0.501236  1.000000  0.667765        0.001816
# 1             2         60   0.502123  1.000000  0.668551        0.003481
# 2             2         70   0.503372  0.999295  0.669500        0.008172
# 3             2         80   0.505908  0.995772  0.670940        0.016041
# 4             2         90   0.511840  0.990134  0.674832        0.034958

# %%
df1 = pca_res.iloc[45:90][:]
# df1

# %%
df2 = pca_res.iloc[90:135][:]
# df2

# %%
df3 = pca_res.iloc[135:180][:]

# %%
df4 = pca_res.iloc[180:225][:]

# %%
plt.plot(df4['Threshold'], df4['Train_accuracy'], label='Train Accuracy', color = 'red')
plt.plot(df4['Threshold'], df4['Precision'], label='Precision',color = 'orange')
plt.plot(df4['Threshold'], df4['Recall'], label='Recall',color = 'blue')
plt.plot(df4['Threshold'], df4['F1_score'], label='F1 Score',color = 'green')
plt.xlabel("Error Threshold Values")
plt.ylabel("Score ")
# plt.legend(title='score', bbox_to_anchor = (1,1.35), loc='upper right', )
plt.legend(title='score', loc='upper right')
plt.title("Trend in results, where PCA Components = 6")
plt.show()
